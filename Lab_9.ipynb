# %% [markdown]
# <a href="https://colab.research.google.com/github/241b218-cpu/Sahil-APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = set()
    distances[start] = 0
    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        if min_node is None:
            break
        visited.add(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node
    return distances, previous
def get_path(previous, start, end):
    path = []
    current = end
    while current is not None:
        path.append(current)
        current = previous[current]
    path.reverse()
    if path[0] == start:
        return path
    return []
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1}: ")
    graph[node] = {}

for node in graph:
    edges = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(edges):
        neighbor = input("  Neighbor node: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight
print("\nAdding two extra nodes (X and Y)...")
graph['X'] = {'Y': 3}
graph['Y'] = {'X': 3}
while True:
    start = input("\nEnter source node (or 'exit' to quit): ")
    if start.lower() == 'exit':
        break
    if start not in graph:
        print("Invalid node!")
        continue
    distances, previous = dijkstra(graph, start)
    print("\nShortest distances from", start)
    for node in graph:
        print(f"{node} : {distances[node]}")
    print("\nPaths:")
    for node in graph:
        path = get_path(previous, start, node)
        if path:
            print(f"{start} -> {node} : {' -> '.join(path)} (Cost: {distances[node]})")
        else:
            print(f"No path to {node}")
# Out:
# Enter number of nodes: 4
# Enter node 1: A
# Enter node 2: B
# Enter node 3: C
# Enter node 4: D
# Enter number of neighbors for A: 2
#   Neighbor node: B
#   Weight: 4
#   Neighbor node: C
#   Weight: 2
# Enter number of neighbors for B: 1
#   Neighbor node: D
#   Weight: 5
# Enter number of neighbors for C: 2
#   Neighbor node: B
#   Weight: 1
#   Neighbor node: D
#   Weight: 8
# Enter number of neighbors for D: 0
#
# Adding two extra nodes (X and Y)...
#
# Enter source node (or 'exit' to quit): A
#
# Shortest distances from A
# A : 0
# B : 3
# C : 2
# D : 8
# X : inf
# Y : inf
#
# Paths:
# A -> A : A (Cost: 0)
# A -> B : A -> C -> B (Cost: 3)
# A -> C : A -> C (Cost: 2)
# A -> D : A -> C -> B -> D (Cost: 8)
# No path to X
# No path to Y
#
# Enter source node (or 'exit' to quit): C
#
# Shortest distances from C
# A : inf
# B : 1
# C : 0
# D : 6
# X : inf
# Y : inf
#
# Paths:
# No path to A
# C -> B : C -> B (Cost: 1)
# C -> C : C (Cost: 0)
# C -> D : C -> B -> D (Cost: 6)
# No path to X
# No path to Y
#
# Enter source node (or 'exit' to quit): EXIT

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = set()
    distances[start] = 0
    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        if min_node is None:
            break
        visited.add(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node
    return distances, previous
def get_path(previous, start, end):
    path = []
    while end is not None:
        path.append(end)
        end = previous[end]
    path.reverse()
    return path
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1}: ")
    graph[node] = {}
for node in graph:
    edges = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(edges):
        neighbor = input("  Neighbor: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight
print("\nAdding two extra nodes X and Y...")
graph['X'] = {'Y': 3}
graph['Y'] = {'X': 3}
while True:
    start = input("\nEnter source node (or 'exit' to stop): ")
    if start.lower() == 'exit':
        break
    if start not in graph:
        print("Invalid source node!")
        continue
    distances, previous = dijkstra(graph, start)
    print(f"\nShortest paths from {start}:\n")
    for node in graph:
        if distances[node] == float('inf'):
            print(f"{start} -> {node} : No path")
        else:
            path = get_path(previous, start, node)
            print(f"{start} -> {node} : {' -> '.join(path)} (Distance: {distances[node]})")
# Out:
# Enter number of nodes: 4
# Enter node 1: A
# Enter node 2: B
# Enter node 3: C
# Enter node 4: D
# Enter number of neighbors for A: 2
#   Neighbor: B
#   Weight: 4
#   Neighbor: C
#   Weight: 2
# Enter number of neighbors for B: 3
#   Neighbor: A
#   Weight: 4
#   Neighbor: C
#   Weight: 5
#   Neighbor: D
#   Weight: 10
# Enter number of neighbors for C: 3
#   Neighbor: A
#   Weight: 2
#   Neighbor: B
#   Weight: 5
#   Neighbor: D
#   Weight: 3
# Enter number of neighbors for D: 2
#   Neighbor: B
#   Weight: 10
#   Neighbor: C
#   Weight: 3
#
# Adding two extra nodes X and Y...
#
# Enter source node (or 'exit' to stop): A
#
# Shortest paths from A:
#
# A -> A : A (Distance: 0)
# A -> B : A -> B (Distance: 4)
# A -> C : A -> C (Distance: 2)
# A -> D : A -> C -> D (Distance: 5)
# A -> X : No path
# A -> Y : No path
#
# Enter source node (or 'exit' to stop): C
#
# Shortest paths from C:
#
# C -> A : C -> A (Distance: 2)
# C -> B : C -> B (Distance: 5)
# C -> C : C (Distance: 0)
# C -> D : C -> D (Distance: 3)
# C -> X : No path
# C -> Y : No path
#
# Enter source node (or 'exit' to stop): EXIT

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
